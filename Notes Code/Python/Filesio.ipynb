# %%
f = open("demo.txt","r")
data = f.read()
print(data)
f.close()
# Out:
# We got new data 1001

# %%
f = open("demo.txt","r")
data = f.read(5)
print(data)
# Out:
# We go

# %%
f = open("demo.txt","r")
line1 = f.readline()
print(line1)

line2 = f.readline()
print(line2)
# Out:
# We got new data 1001

# %%
f = open("demo.txt", "w")
f.write("I want to learn Apache Kafka")
# Out:
# 28

# %%
f = open("demo.txt","a")
f.write("\n And also Power BI")
# Out:
# 19

# %%
f = open("sample.txt", "w")
f.close()

# %%
f = open("demo.txt", "r+")
f.write("Aagg")
# Out:
# 4

# %%
f = open("demo.txt", "w+")
f.read()
# Out:
# 'Aagg'

# %%
f = open("demo.txt", "a+")
f.read()
f.write("abc")
# Out:
# 3

# %%
with open("demo.txt","r" ) as f:
    data = f.read()
    print(data)
# Out:
# Aaggabc

# %%
with open("demo.txt","w" ) as f:
    data = f.write("We got new data 1001")

# %%
import os
os.remove("demo.txt")

# %%
import os
os.remove("sample.txt")
