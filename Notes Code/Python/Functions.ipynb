# %%
a = 10
b = 20

def sum(a , b):
    sum = a + b
    return sum

print(sum(a,b))
# Out:
# 30

# %%
def show(n):
    if(n==0):
    
        return   
    print(n)
    show(n-1)

show(5)
# Out:
# 5
# 4
# 3
# 2
# 1
